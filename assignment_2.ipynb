# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
#
# **Ans:** True and False
#
# 2. What are the three different types of Boolean operators?
#
# **Ans:** AND, OR, NOT
#
# 3. Make a list of each Boolean operator&#39;s truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
#
#     **Ans:** Below is the table -
#
#     |      A      |      B    | A and B  |    A or B  |
#
#     | True      |  True   |  True        |    True    |
#
#     | False     |  False  |  True        |    False   |
#
#     | True      |  False  |  False       |    True    |
#
#     | False     |  True   |  False       |    True    |
#
#
# 4. What are the values of the following expressions?
#
#     1. (5 &gt; 4) and (3 == 5)
#
#     2. not (5 &gt; 4)
#
#     3. (5 &gt; 4) or (3 == 5)
#
#     4. not ((5 &gt; 4) or (3 == 5))
#
#     5. (True and True) and (True == False)
#
#     6. (not False) or (not True)
#
#     **Ans:**
#         1. False
#         2. False
#         3. True
#         4. False
#         5. False
#         6. True
#
#
# 5. What are the six comparison operators?
#     **Ans:** The comparison operators are - >, <, >=, <=, ==, !=
# 6. How do you tell the difference between the equal to and assignment operators? Describe a condition and when you would use one.
#     **Ans:** Assinment will use only single equal to operator, whereas equal to comparation will be using dobule equal to sign. Example is below -
#     ```
#     #assignment statment
#     a = 5
#     #equal to comparision
#     if(a == 5)
#         print('condition matched')
#     else
#         print('condition didn't match)
#
#     ```
#
# 7. Identify the three blocks in this code:
# ```
# spam = 0
# if spam == 10:
# 	print('eggs')
# if spam > 5:
# 	print('bacon')
# else:
# 	print('ham')
# 	print('spam')
# 	print('spam')
# ```
#
# **Ans:**  Thee blocks are - if, if and else
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints
# Greetings! if anything else is stored in spam.
#
# **Ans:**
#
# ```
# spam = 1
# if spam == 1:
# 	print('Hello')
# elif spam > 2:
# 	print('Howdy')
# else:
# 	print('Greetings!')
#
# ```
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
#
#    **Ans:** ctl + c
#
# 10. How can you tell the difference between break and continue?
#
#     **Ans:** break is to end the loop. Wheareas continue is used to jump on the next iteration without executing the statements mentioned below to the continue statement in the loop.
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
#     **Ans:** Actually there is no deifference between these. All these three return the range object containing values from 0 to 10.
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
#     **Ans:**
#     ```
#     for i in range(1, 11):
#         print(i)
#
#     i = 0
#     while i < 10:
#         i += 1
#         print(i)
#     ```
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after
# importing spam?
#
#    **Ans:** We have to import spam module in our script and then we can call it using module name + dot + methodname. Example is below -
#    ```
#    import spam
#    spam.bacon()
#    ```
